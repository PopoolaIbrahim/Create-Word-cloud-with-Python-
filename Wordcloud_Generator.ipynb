# %% [markdown]
# <a href="https://colab.research.google.com/github/PopoolaIbrahim/Create-Word-cloud-with-Python-/blob/main/Wordcloud_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
 # Import required libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a string of words
text = '''Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python Python Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python PythonData Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Python JavaScript JavaScript JavaScript JavaScript JavaScript JavaScript Numpy Pandas Matplotlib Seaborn Keras Tensorflow Fastai Python Python Pytorch Python Python Python Python Python Python Python Python Python Python Python Python Python Python'''

# Generate word cloud
wordcloud = WordCloud(width=1284, height=321, background_color='white',random_state=100, relative_scaling=0).generate(text)

# Show the generated image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Save the image to a file
wordcloud.to_file("wordcloud.png")
